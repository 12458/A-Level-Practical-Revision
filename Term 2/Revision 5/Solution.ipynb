# %% [markdown]
# # Q1
# Implement a regular Binary Search Tree (BST) using object-oriented programming.
#
# Your BST implementation should include the following:
# - A node class representing each node in the BST
# - A BST class which includes:
#     - 1 attribute: root
#     - 4 methods: __init__(), insert(OBJECT), exists(OBJECT), count(), and print()
# - The exists(OBJECT) method will return TRUE if the target OBJECT is found within the tree, or else returns FALSE.
# - The count() method will return the number of OBJECTs currently stored in the tree.
# - The print() method will print all the OBJECTs in the tree in ascending sorted order – i.e., by using an In-Order Traversal.

# %% [markdown]
# # Q2
# ![image.png](attachment:fbf8c23e-0d81-46e1-acc7-1463f5f2d0e8.png)
